# %% [markdown]
# # Predicting Industry and Job Roles from Job Descriptions: A Multi-Task Learning Perspective
#
# Learning Team 3
# - Francis Mark Cayco
# - Marianne Reyes
# - Imee Lanie Uy
# - Denver Valera
#
# **COSCI 221 - Machine Learning 1** <br>
# Master of Science in Data Science 2025
#
# ## Introduction
# Many prediction tasks demand multiple outputs, not just a single label. Multi-output learning, a subset of supervised learning, is designed to handle these scenarios. Unlike traditional classification, multi-output models can predict multiple interdependent labels simultaneously.
# Multi-output learning can be categorized based on the number and nature of target variables, as illustrated in the table below:
#
# | Classification Type | Number of targets | Target cardinality | Valid `type_of_target` |
# |---|---|---|---|
# | Multiclass classification | 1 | >2 | `'multiclass'` |
# | Multilabel classification | >1 | 2 (0 or 1) | `'multilabel-indicator'` |
# | Multiclass-multioutput classification | >1 | >2 | `'multiclass-multioutput'` |
# | Multioutput regression | >1 | Continuous | `'continuous-multioutput'` |
#
# *Table 1: Types of Multiclass and Multioutput Tasks*
#
# ### Problem Statement
# Job platforms often provide job descriptions along with specific identifiers like industry and employment status (e.g., full-time, part-time, contractual). The study aims to address the question: Can these identifiers be accurately predicted solely from the job description?
#
# The study will utilize the Job Description dataset from Kaggle. The primary objective is to build a model capable of predicting the correct industry and employment status based solely on the provided job description.
#
# **MultiOutputClassifier**
#
# To address this multi-output prediction problem, the group will employ a Multi-Output Classification approach as it involves >1 targets and >2 target cardinality. The job descriptions will serve as input features, while the target variables will be the job type and category. By training a multi-output model, the group aims to accurately classify job listings based on their textual content.
#
# ![image.png](attachment:image.png)
#
# ### Highlights (Please Update this part to include importance of the dependency of the labels)
#
# 1. **Complexity**
#
# Multi-output learning models aim to provide a generalized algorithm for simultaneously predicting multiple outputs. Interpreting these models can be more challenging as they deal with multiple target variables. This complexity increases with the number of target variables and their interdependencies, requiring the model to learn intricate relationships between them. To effectively capture these relationships and improve the model's performance, a substantial amount of data is often necessary. Larger datasets can help the model identify subtle patterns and correlations.
#
# 2. **Error Propagation**
#
# There is a higher chance of errors with multi-output algorithms because they predict multiple target variables simultaneously. An error in one output can overshadow the good accuracy of another, especially if the outputs have varying levels of importance. This impact is more pronounced when the target variables are interrelated. For example, misclassifying a job type while correctly identifying the industry category can create practical issues for both employers and job seekers, as the outputs are often used together in decision-making.
#
# 3. **Evaluation Metrics**
#
# The MultiOutputClassifier in the scikit-learn library does not have a built-in scoring metric. This necessitates the creation of custom evaluation metrics to assess the model's performance. One approach is to calculate accuracy for each target variable individually and then combine these scores into a weighted average. Alternatively, comparing the performance of a multi-output model against separate single-output models can provide insights into the trade-offs between complexity and performance. However, it's important to consider the computational cost and training time associated with multi-output models. A more complex model may require significant computational resources and longer training times. Therefore, it's crucial to balance model complexity with practical considerations like computational efficiency and deployment time.

# %%
# %pip install -r requirements.txt

# %%
import multiprocessing as mp
import re

import numpy as np
import pandas as pd
import requests
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import nltk
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from langdetect import detect
from scipy.stats import chi2_contingency
from sklearn.decomposition import TruncatedSVD
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, make_scorer
from sklearn.model_selection import (GridSearchCV, RandomizedSearchCV, ShuffleSplit, cross_validate,
                                     train_test_split)
from sklearn.multioutput import MultiOutputClassifier, ClassifierChain
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from tqdm import tqdm

from utils import translate

nltk.download(['punkt_tab','wordnet'])

RANDOM_STATE = 420
np.random.seed(RANDOM_STATE)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/francismarkcayco/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/francismarkcayco/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# <div class="alert alert-info">
#
# ## Exploratory Data Analysis
# </div>

# %%
df = pd.read_csv('dataset.csv')
df.head(5)
# Out:
#      job_no                                    job_description  \
# 0  Id-12765   Zest Scientific is searching for an accomplis...
# 1  Id-22925  En el mundo de los CRO's típicos, esta compañí...
# 2   Id-1321  Asha Mistry of Umbilical Life is recruiting an...
# 3   Id-9473   Sales Representative - Laser in der Medizinte...
# 4  Id-14952  Field Service Engineer - Life Science\r\r\r\nC...
#
#            job_type                                      category
# 0         Permanent  Pharmaceutical, Healthcare and Medical Sales
# 1         Permanent                             Clinical Research
# 2  Contract/Interim                      Pharmaceutical Marketing
# 3         Permanent  Pharmaceutical, Healthcare and Medical Sales
# 4         Permanent                    Manufacturing & Operations

# %%
df['category_short'] = df['category'].apply(lambda x: x[:10] + '...' if len(x) > 10 else x)
label_counts = pd.crosstab(df['job_type'], df['category_short'],normalize='all')
fig = plt.figure(figsize=(10, 8))
gs = gridspec.GridSpec(2, 2, height_ratios=[1, 1])

ax1 = fig.add_subplot(gs[0, :])
sns.heatmap(label_counts, cmap='YlGnBu', ax=ax1, cbar=True, linecolor='black', center=0.01)
ax1.set_ylabel('Job Type')
ax1.set_xlabel('Job Category')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')
ax1.set_title('Class Contingency Matrix')
ax1.legend(title='% Occurence', bbox_to_anchor=(1.05, 1), loc='best')

ax2 = fig.add_subplot(gs[1, 0])
ax2.set_title('Job Type Distribution')
sns.countplot(df['job_type'], ax=ax2, stat='percent')

ax3 = fig.add_subplot(gs[1, 1])
ax3.set_title('Job Category Distribution')
sns.countplot(df['category_short'], ax=ax3, stat='percent') 

plt.subplots_adjust(hspace=0.5, wspace=0.3) 
plt.tight_layout()
plt.show()
# Out:
# /var/folders/94/qqxkptrd1bg66t_3104htv1m0000gn/T/ipykernel_97567/1984838821.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(title='% Occurence', bbox_to_anchor=(1.05, 1), loc='best')

# %% [markdown]
# The data appears to be imbalanced in several ways. Firstly, the distribution of job types is skewed towards "Permanent" roles, with other types like "Part-Time" and "Temporary/Seasonal" being significantly underrepresented. This suggests that the dataset may not accurately reflect the full spectrum of job types in the relevant job market. Secondly, certain job categories, such as "Pharmaceuticals" and "Clinical Research," are more prevalent than others, indicating a potential bias towards specific industries or sectors. This imbalance could lead to a model that is less accurate in predicting less common job types or categories.

# %%
job_type_distribution = df['job_type'].value_counts().reset_index()
job_type_distribution['percentage'] = job_type_distribution['count'] / job_type_distribution['count'].sum()
job_type_pcc = np.sum(job_type_distribution['percentage']**2)

print(f"PCC of Job Type Distribution: {job_type_pcc:.2f}")

category_distribution = df['category_short'].value_counts().reset_index()
category_distribution['percentage'] = category_distribution['count'] / category_distribution['count'].sum()
category_pcc = np.sum(category_distribution['percentage']**2)
print(f"PCC of Job Category Distribution: {category_pcc:.2f}")

print("Overall PCC: {:.2f}".format((job_type_pcc + category_pcc) / 2))
# Out:
# PCC of Job Type Distribution: 0.81
# PCC of Job Category Distribution: 0.19
# Overall PCC: 0.50

# %% [markdown]
# High PCC for job type indicates a significant imbalance in the distribution of job types.  A high PCC means one or a few classes (in this case, job types like "Permanent") dominate the dataset.
#
# Meanwhile, the low PCC for job category suggests a more balanced distribution across job categories. While less imbalanced than job type, certain categories like "Pharmaceuticals" and "Clinical Research" were still more frequent than others.

# %% [markdown]
# ### Assumption of Label Independence
#
# In multiclass, multioutput classification, the assumption of dependence on a multioutput class means that the multiple output labels are **not independent** of each other. They are somehow related or correlated, and predicting them together, considering their dependencies, can lead to better performance than predicting each independently.
#
# The test also determines if we can either (1) train each label independently or (2) train them together. If the labels are dependent, training them together is more beneficial.
#
#
# In order to test if the two labels are dependent, we can use the Chi-Square test of independence. The Chi-Square test of independence is a statistical test used to determine whether there is a significant association between two categorical variables. In this case, we can use it to determine if the job type and job category are dependent on each other.

# %%
stat, p, _, _ = chi2_contingency(label_counts)
print(f'Chi-Square Statistic: {stat:.3f}')
print(f'P-value: {p:.3f}')
# Out:
# Chi-Square Statistic: 0.034
# P-value: 1.000

# %% [markdown]
# Assuming that our significance value is 0.05 and the p-value is 1.0, we fail to reject the null hypothesis. This means that the two labels are independent of each other. There is no statistically significant association between the two categorical variables represented.
#
# Even if there is no statistically significant relationship between the two, the analysis will involve training the labels together, and training them independently will be considered as a baseline model.  ***We will see if the test dataset will have a better performance when the labels are trained together compared to when they are trained independently.***

# %% [markdown]
# <div class="alert alert-info">
#
# ## Preprocessing and Feature Extraction
# </div>

# %% [markdown]
# There are four columns: `job_no`, `job_description`, `job_type`, and `category`.  The last two columns are the labels while the `job_decription` is the feature.  Upon inspecting the contents of the `job_description`, some rows are not in English.  Instead of deleting them, we opted to translate the contents into English.

# %%
df['lang'] = df['job_description'].apply(detect)

# %% [markdown]
# ### Text Translation

# %% [markdown]
# `landetect` is a language detection library ported from Java.  It has the following features:
# - Generate language profiles from Wikipedia abstract xml
# - Detect language of a text using naive Bayesian filter
# - 99% over precision for 53 languages
#
# The language detection algorithm is non-deterministic, but it is consistent in the sense that the same text will always return the same language.
#
# Source: https://github.com/shuyo/language-detection/blob/wiki/ProjectHome.md

# %%
df['lang'].value_counts(normalize=True)*100
# Out:
# lang
# en    69.972249
# es     9.973382
# fr     9.928074
# de     9.877103
# it     0.215212
# sv     0.033981
# Name: proportion, dtype: float64

# %% [markdown]
# 70% of the `job_description`s are written in English.  The rest are written in Español, Français, and Deutsch, Italiano, and Swedish.
#
# To translate the non-English `job_description`s, we used `libretranslate`, a free and open-source machine translation service.  The self-hosted version of `libretranslate` is used in this project.  To install the API server, follow the instructions in the [libretranslate repository](https://github.com/LibreTranslate/LibreTranslate?tab=readme-ov-file#install-and-run).
#
# In your CLI, run the following command:
#
# `libretranslate --load-only de,it,sv,en,es,fr --update-models --debug`
#
# Create a request to the localhost translation API.  Note that due to `multiprocessing` library limitations, the method is imported instead of being defined in the notebook.
# ```
# def translate(args):
#     text, source = args
#     url = "http://127.0.0.1:5000/translate"
#     body = {
#         "q": text,
#         "source": source,
#         "target": "en",
#         "format": "text",
#     }
#     response = requests.post(url, json=body)
#
#     if response.status_code != 200:
#         raise Exception(response.json())
#
#     return response.json()["translatedText"]
# ```

# %% [markdown]
# <div class="alert alert-warning">
#
# ### Performance Warning
#
# The translation process is time-consuming.  It took ~10 hours to translate 5301 rows of non-English `job_description`s.  This could take a lot longer when ran in Jojie or Google Colab.
#
# ![image.png](attachment:image.png)
#
# Skip this step if you have already translated the non-English `job_description`s and proceed to the cell reading the `dataset_translated.csv` file.
# </div>

# %%
df_english = df[df['lang'] == 'en'].copy()
df_non_english = df[df['lang'] != 'en'].copy()

with mp.Pool(mp.cpu_count()) as pool:
    args = [(text, lang) for text, lang in zip(df_non_english['job_description'], df_non_english['lang'])]
    results = list(tqdm(pool.imap(translate, args), total=len(df_non_english)))
    df_non_english['job_description_translated'] = results
# Out:
# 100%|██████████| 5301/5301 [9:51:39<00:00,  6.70s/it]

# %%
df_english['job_description_translated'] = df_english['job_description']
df = pd.concat([df_english, df_non_english])
df.to_csv('dataset_translated.csv', index=False)

# %% [markdown]
# Read the translated dataset.

# %%
df = pd.read_csv('dataset_translated.csv')
df.head(5)
# Out:
#      job_no                                    job_description  \
# 0  Id-12765   Zest Scientific is searching for an accomplis...
# 1   Id-1321  Asha Mistry of Umbilical Life is recruiting an...
# 2   Id-9473   Sales Representative - Laser in der Medizinte...
# 3  Id-14952  Field Service Engineer - Life Science\r\r\r\nC...
# 4  Id-16692   Due to increased business demand this award w...
#
#            job_type                                      category lang  \
# 0         Permanent  Pharmaceutical, Healthcare and Medical Sales   en
# 1  Contract/Interim                      Pharmaceutical Marketing   en
# 2         Permanent  Pharmaceutical, Healthcare and Medical Sales   en
# 3         Permanent                    Manufacturing & Operations   en
# 4         Permanent  Pharmaceutical, Healthcare and Medical Sales   en
#
#                           job_description_translated
# 0   Zest Scientific is searching for an accomplis...
# 1  Asha Mistry of Umbilical Life is recruiting an...
# 2   Sales Representative - Laser in der Medizinte...
# 3  Field Service Engineer - Life Science\r\r\r\nC...
# 4   Due to increased business demand this award w...

# %%
df_unique = df[['job_type','category','lang','job_description_translated']].drop_duplicates()

print(f"Number of unique job descriptions: {len(df_unique)}")
# Out:
# Number of unique job descriptions: 9444

# %% [markdown]
# ### Tokenization
#
# For the tokenization process, we used the `nltk` library and some RegEx:
# - Remove special characters
# - Remove numbers
# - Remove characters of length 1 and 2.
# - Word tokenizes using nltk's `word_tokenize` function.
# - Lemmatize the words using nltk's `WordNetLemmatizer`.
# - Translates British English to American English.

# %%
class LemmaTokenizer:
    def __init__(self):
        self.wnl = WordNetLemmatizer()

        url ="https://raw.githubusercontent.com/hyperreality/American-British-English-Translator/master/data/american_spellings.json"
        self.american_british_dict = requests.get(url).json()

    def __call__(self, doc):
        doc = re.sub(r'\W+', ' ', doc)
        doc = re.sub(r'\b\w{1,2}\b', '', doc)
        doc = re.sub(r'\d+', '', doc)

        words = []
        for t in word_tokenize(doc):
            word = self.wnl.lemmatize(t)
            word = self.american_british_dict.get(word, word)
            words.append(word)
        return words

# %% [markdown]
# ### Feature Extraction
# We used the `TfidfVectorizer` to convert the `job_description` into a matrix of TF-IDF features.

# %%
vectorizer = TfidfVectorizer(
    tokenizer=LemmaTokenizer(),
    stop_words='english',
    strip_accents = 'unicode',
    )
X = vectorizer.fit_transform(df_unique['job_description_translated'])
print("Shape: ", X.shape)
print("Sample features: ", vectorizer.get_feature_names_out()[10:])
# Out:
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:406: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'wa'] not in stop_words.
#   warnings.warn(
# Shape:  (9444, 13324)
# Sample features:  ['ab' 'abandon' 'abandonment' ... 'zurich' 'zweck' 'zwingend']

# %% [markdown]
# ## TODO: Balance Dataset Here

# %% [markdown]
# ### Dimensionality Reduction
#
# Since we have `13324` features and `9444` samples, we used the `TruncatedSVD` to reduce the dimensionality of the dataset to $N$ features.
#
# Why `TruncatedSVD`?
# - Does not require the input data to be mean-centered.
# - It is faster than PCA
# - Works with sparse matrices which commonly occurs in TF-IDF matrices.
#
# See how much variance is explained by the first `4000` components

# %%
svd = TruncatedSVD(4000)
X_svd = svd.fit_transform(X)

# %%
variance_explained = svd.explained_variance_.cumsum()
plt.plot(range(1, len(variance_explained)+1), variance_explained, 'o-')
plt.xlabel('Principal Component')
plt.ylabel('Cumulative Variance Explained')

for variance in [0.7,0.75, 0.8, 0.85, 0.88,0.9]:
    print(f"# of components to explain {variance*100}% of variance: {np.argwhere(variance_explained > variance)[0][0]}")
# Out:
# # of components to explain 70.0% of variance: 715
# # of components to explain 75.0% of variance: 929
# # of components to explain 80.0% of variance: 1242
# # of components to explain 85.0% of variance: 1768
# # of components to explain 88.0% of variance: 2359
# # of components to explain 90.0% of variance: 3153

# %% [markdown]
# For this project, we used the first `1768` components as it already explains 85% of the variance.

# %%
X_svd = X_svd[:, :np.argwhere(variance_explained > 0.85)[0][0]]
X_svd.shape
# Out:
# (9444, 1768)

# %% [markdown]
# ### Label Encoding
#
# Transform the categorical labels to numerical values using `LabelEncoder`.

# %%
job_type_encoder = LabelEncoder()
category_encoder = LabelEncoder()

df_unique['job_type'] = job_type_encoder.fit_transform(df_unique['job_type'])
df_unique['category'] = category_encoder.fit_transform(df_unique['category'])

y = df_unique[['job_type','category']]
df_unique
# Out:
#        job_type  category lang  \
# 0             4         6   en
# 1             1         5   en
# 2             4         6   en
# 3             4         2   en
# 4             4         6   en
# ...         ...       ...  ...
# 17650         4        10   es
# 17651         4         9   fr
# 17652         4         2   fr
# 17653         4         2   de
# 17654         4         4   de
#
#                               job_description_translated
# 0       Zest Scientific is searching for an accomplis...
# 1      Asha Mistry of Umbilical Life is recruiting an...
# 2       Sales Representative - Laser in der Medizinte...
# 3      Field Service Engineer - Life Science\r\r\r\nC...
# 4       Due to increased business demand this award w...
# ...                                                  ...
# 17650  Veterinary pathologist with scientific respons...
# 17651  Experienced medical writing - Germany - Advice...
# 17652  QMS specialists - German Switzerland - growing...
# 17653  Alcon, United Kingdom\nWould you like to work ...
# 17654  I currently work with a rapidly growing, world...
#
# [9444 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-info">
#
# ## Part 1: Model Training - Independent Labels
#
# `sklearn.multioutput.MultiOutputClassifier` is a type of machine learning model that can predict multiple target variables simultaneously for a given input.  Instead of predicting just one output, like in traditional classification, it predicts two or more outputs.  In this type, we treat each output independently and assumes that they are not related to each other.
#
# The following models already upport multi-class multi-output classification so they do not require to be wrapped inside `MultiOutputClassifier`:
# - **DecisionTreeClassifier, RandomForestClassifier, ExtraTreesClassifier, and GradientBoostingClassifier**
#
#   At each node, decision trees find the best split based on all output labels simultaneously. They can naturally predict multiple outputs at leaf nodes. This extends to ensembles like Random Forests and Gradient Boosting.
#
# - **KNeighborsClassifier and RadiusNeighborsClassifier**
#
#   KNN directly uses the labels of the k nearest neighbors to predict multiple outputs. It doesn't have a separate training phase, so it can readily adapt to multiple output labels.
#
# Meanwhile, some models that do not support multi-class multi-output classification has to be wrapped inside `MultiOutputClassifier`.  Examples include:
# - **LogisticRegression and Support Vector Machines**
#
#   These models are traditionally designed for single-output problems. They optimize a single decision boundary or set of weights for one output.
#
# - **Naive Bayes**
#
#   Built on the "naive" assumption that features are conditionally independent given the class label. This means it calculates the probability of each feature occurring independently of other features, given a specific class.
#
# We wil compare the results between labels trained independently and labels trained together.
# </div>

# %%
x_train, x_test, y_train, y_test = train_test_split(X_svd, y, test_size=0.25)
# Validation set is already included in the training set

# %% [markdown]
# ### Define a custom scoring function
# Sklearn [does not have a native metric](https://scikit-learn.org/1.5/modules/multiclass.html#multiclass-multioutput-classification)  to support multiclass multioutput classification .  We created a custom scoring function that computes the F1 score for each class and averages them.

# %%
def f1_multiclass_multioutput(y_true,y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    return np.mean([f1_score(y_true[:, i], y_pred[:, i], average='micro') for i in range(y_true.shape[1])])

# %% [markdown]
# ### Model Selection
#
# For hyperparameter tuning, we used the `GridSearchCV` with the custom scoring function and `n_iter` of 100.
#
# For the cross-validation, we used the `ShuffleSplit` (equivalent to Monte-Carlo CV) with `n_splits=5`.  We used the following models:

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.25) # test size equal to the validation set
param_grid = [
    {
        "clf": [DecisionTreeClassifier(), RandomForestClassifier(), ExtraTreeClassifier(), ExtraTreesClassifier()],
        'clf__max_depth': [10, 30, 50],
        'clf__min_samples_split': [2, 10, 100],
    },
    {
        "clf": [KNeighborsClassifier()],
        'clf__n_neighbors': [5, 10, 100],
        'clf__weights': ['uniform', 'distance'],
    },
    {
        "clf": [MultiOutputClassifier(LogisticRegression())],
        "clf__estimator__penalty": ['l1','l2'],
        "clf__estimator__C": [0.01, 0.1, 1.5, 2.5, 3, 4.5, 6, 7.5, 10],
    },
    {
        "clf": [RadiusNeighborsClassifier()],
        'clf__radius': [1,5,10,15],
        'clf__weights': ['uniform', 'distance'],
    },
    # Removed SVC due to long training times
    # { #
    #     "clf": [MultiOutputClassifier(SVC())],
    #     "clf__estimator__C": [0.01, 0.1, 1.4, 10],
    # }
]

steps = [('clf', None)]
pipe = Pipeline(steps)
clf = RandomizedSearchCV(pipe,
                         param_distributions=param_grid,
                         n_iter=100,
                         cv=cv,
                         n_jobs=-1,
                         scoring=make_scorer(f1_multiclass_multioutput),
                         verbose=2) # ,
clf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 68 candidates, totalling 340 fits
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 68 is smaller than n_iter=100. Running 68 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=  10.6s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=  10.6s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=  10.6s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=  10.9s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=  11.0s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=  10.9s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=  11.2s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=  11.3s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=  10.9s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=  11.0s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=  11.0s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=  11.1s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=  11.8s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=  11.8s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=  12.1s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  17.7s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  17.1s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  16.5s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  17.5s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  17.5s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  18.3s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  18.4s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  18.9s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  19.1s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=  16.5s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=  17.1s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=  17.9s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=  18.5s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=  18.2s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  21.8s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  21.1s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  20.9s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  20.1s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  20.4s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  22.3s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  20.6s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  21.9s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  19.8s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  21.0s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  22.6s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  18.8s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  18.3s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  19.6s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  19.8s
# [CV] END clf=DecisionTreeClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  19.8s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=  24.6s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=  24.2s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=  23.8s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=  23.4s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=  23.7s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=  22.8s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=  22.7s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=  24.1s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=  24.4s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=  25.1s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=  23.6s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=  23.8s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=  24.1s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=  24.6s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=  24.4s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  45.0s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  45.2s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  48.5s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  48.5s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  45.5s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  45.4s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  50.6s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  48.1s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  51.4s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=  44.8s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  52.9s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=  42.3s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=  41.8s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=  41.7s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=  42.2s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  55.6s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  53.1s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  54.7s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  53.0s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  49.1s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  50.2s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  53.9s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  49.8s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=   0.4s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=   0.2s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreeClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=   0.1s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=   4.1s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  47.4s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=   4.0s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=   4.5s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=   4.1s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=2; total time=   4.4s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=   4.3s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=   4.4s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=   4.5s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=   4.3s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=10; total time=   4.4s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=   3.9s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  38.3s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  39.6s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=   4.0s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  48.1s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  39.7s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  40.5s
# [CV] END clf=RandomForestClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  39.6s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=   4.6s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=   4.9s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=10, clf__min_samples_split=100; total time=   5.2s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  10.6s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  10.3s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  10.3s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  14.7s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  15.9s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  15.2s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  15.4s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=2; total time=  15.4s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=   7.7s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=   7.6s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=   7.9s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  11.0s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=10; total time=  10.8s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=   7.5s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=30, clf__min_samples_split=100; total time=   7.5s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  16.4s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  10.4s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  10.7s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  10.6s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  15.4s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  15.9s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  16.1s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=2; total time=  16.8s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=5, clf__weights=uniform; total time=   0.9s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=5, clf__weights=uniform; total time=   0.8s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=   8.2s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=5, clf__weights=uniform; total time=   0.8s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=5, clf__weights=uniform; total time=   0.8s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=   8.8s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=5, clf__weights=uniform; total time=   0.8s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=5, clf__weights=distance; total time=   0.9s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=5, clf__weights=distance; total time=   1.0s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=5, clf__weights=distance; total time=   1.2s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=5, clf__weights=distance; total time=   0.9s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=5, clf__weights=distance; total time=   1.0s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=10, clf__weights=uniform; total time=   1.0s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=10, clf__weights=uniform; total time=   1.0s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  12.6s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=10, clf__weights=uniform; total time=   1.1s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=10, clf__weights=uniform; total time=   1.1s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=10, clf__weights=uniform; total time=   1.0s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=10, clf__weights=distance; total time=   1.2s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  10.8s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=10, clf__weights=distance; total time=   1.0s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=10, clf__weights=distance; total time=   1.1s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=10; total time=  14.1s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  10.6s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=10, clf__weights=distance; total time=   1.2s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=10, clf__weights=distance; total time=   1.1s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=100, clf__weights=uniform; total time=   1.6s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=100, clf__weights=uniform; total time=   1.6s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=100, clf__weights=uniform; total time=   1.5s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=100, clf__weights=uniform; total time=   1.6s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.01, clf__estimator__penalty=l1; total time=   0.0s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.01, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=100, clf__weights=distance; total time=   1.5s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.01, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.01, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.01, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=100, clf__weights=uniform; total time=   1.7s
# [CV] END clf=ExtraTreesClassifier(), clf__max_depth=50, clf__min_samples_split=100; total time=  10.7s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=100, clf__weights=distance; total time=   1.7s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=100, clf__weights=distance; total time=   1.1s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=100, clf__weights=distance; total time=   1.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.1, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.1, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=KNeighborsClassifier(), clf__n_neighbors=100, clf__weights=distance; total time=   1.3s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.1, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.1, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.1, clf__estimator__penalty=l1; total time=   0.0s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.01, clf__estimator__penalty=l2; total time=   3.3s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.01, clf__estimator__penalty=l2; total time=   3.3s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.01, clf__estimator__penalty=l2; total time=   3.4s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.01, clf__estimator__penalty=l2; total time=   3.4s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=1.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.01, clf__estimator__penalty=l2; total time=   3.3s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=1.5, clf__estimator__penalty=l1; total time=   0.2s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=1.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=1.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=1.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.1, clf__estimator__penalty=l2; total time=   5.4s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.1, clf__estimator__penalty=l2; total time=   5.7s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.1, clf__estimator__penalty=l2; total time=   5.9s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=2.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=2.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=2.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=2.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=2.5, clf__estimator__penalty=l1; total time=   0.0s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.1, clf__estimator__penalty=l2; total time=   4.7s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=0.1, clf__estimator__penalty=l2; total time=   5.3s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=1.5, clf__estimator__penalty=l2; total time=  11.3s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=1.5, clf__estimator__penalty=l2; total time=  11.3s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=1.5, clf__estimator__penalty=l2; total time=  11.5s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=3, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=3, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=3, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=3, clf__estimator__penalty=l1; total time=   0.0s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=3, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=1.5, clf__estimator__penalty=l2; total time=  10.7s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=1.5, clf__estimator__penalty=l2; total time=  10.5s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=2.5, clf__estimator__penalty=l2; total time=  12.6s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=2.5, clf__estimator__penalty=l2; total time=  12.0s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=2.5, clf__estimator__penalty=l2; total time=  12.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=4.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=4.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=4.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=4.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=4.5, clf__estimator__penalty=l1; total time=   0.2s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=2.5, clf__estimator__penalty=l2; total time=  12.1s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=2.5, clf__estimator__penalty=l2; total time=  12.5s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=3, clf__estimator__penalty=l2; total time=  12.9s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=3, clf__estimator__penalty=l2; total time=  12.4s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=3, clf__estimator__penalty=l2; total time=  12.7s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=6, clf__estimator__penalty=l1; total time=   0.0s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=6, clf__estimator__penalty=l1; total time=   0.0s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=6, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=6, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=6, clf__estimator__penalty=l1; total time=   0.0s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=3, clf__estimator__penalty=l2; total time=  12.4s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=3, clf__estimator__penalty=l2; total time=  12.2s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=4.5, clf__estimator__penalty=l2; total time=  12.5s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=4.5, clf__estimator__penalty=l2; total time=  13.0s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=4.5, clf__estimator__penalty=l2; total time=  13.6s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=7.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=7.5, clf__estimator__penalty=l1; total time=   0.0s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=7.5, clf__estimator__penalty=l1; total time=   0.0s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=7.5, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=7.5, clf__estimator__penalty=l1; total time=   0.1s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=4.5, clf__estimator__penalty=l2; total time=  14.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=4.5, clf__estimator__penalty=l2; total time=  13.3s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=6, clf__estimator__penalty=l2; total time=  13.0s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=6, clf__estimator__penalty=l2; total time=  12.9s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=6, clf__estimator__penalty=l2; total time=  13.7s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=10, clf__estimator__penalty=l1; total time=   0.0s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=10, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=10, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=10, clf__estimator__penalty=l1; total time=   0.1s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=10, clf__estimator__penalty=l1; total time=   0.1s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=6, clf__estimator__penalty=l2; total time=  14.6s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=6, clf__estimator__penalty=l2; total time=  12.4s
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=7.5, clf__estimator__penalty=l2; total time=  11.7s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=7.5, clf__estimator__penalty=l2; total time=  12.5s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=7.5, clf__estimator__penalty=l2; total time=  13.1s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=7.5, clf__estimator__penalty=l2; total time=  13.1s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/pipeline.py", line 601, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 693, in predict
#     probs = self.predict_proba(X)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 782, in predict_proba
#     raise ValueError(
# ...
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/pipeline.py", line 601, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 693, in predict
#     probs = self.predict_proba(X)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 782, in predict_proba
#     raise ValueError(
# ValueError: No neighbors found for test samples array([  22,   26,   66,   80,   88,  106,  119,  144,  169,  172,  183,
#         200,  207,  216,  220,  221,  223,  226,  237,  258,  279,  280,
#         319,  354,  357,  378,  382,  404,  410,  425,  441,  460,  525,
#         535,  546,  549,  554,  558,  563,  564,  567,  568,  593,  599,
#         619,  633,  660,  664,  702,  738,  753,  770,  807,  827,  828,
#         842,  857,  878,  895,  906,  923,  949,  973,  976, 1034, 1044,
#        1079, 1082, 1115, 1143, 1149, 1162, 1187, 1198, 1205, 1216, 1225,
#        1231, 1237, 1264, 1272, 1277, 1283, 1289, 1319, 1339, 1344, 1347,
#        1356, 1359, 1366, 1370, 1378, 1389, 1391, 1402, 1448, 1482, 1492,
#        1493, 1510, 1550, 1552, 1553, 1572, 1578, 1588, 1592, 1618, 1656,
#        1664, 1693, 1713, 1728, 1729, 1731, 1732, 1754, 1765]), you can try using larger radius, giving a label for outliers, or considering removing them from your dataset.
#
#   warnings.warn(
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=1, clf__weights=distance; total time=   1.1s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=1, clf__weights=distance; total time=   1.0s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=10, clf__estimator__penalty=l2; total time=  14.6s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=5, clf__weights=uniform; total time=   1.6s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=5, clf__weights=uniform; total time=   2.2s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=5, clf__weights=uniform; total time=   2.1s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=5, clf__weights=uniform; total time=   2.1s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=5, clf__weights=uniform; total time=   2.7s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=5, clf__weights=distance; total time=   2.1s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=5, clf__weights=distance; total time=   2.2s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=10, clf__estimator__penalty=l2; total time=  16.2s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=5, clf__weights=distance; total time=   1.3s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=5, clf__weights=distance; total time=   2.2s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=10, clf__weights=uniform; total time=   1.6s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=5, clf__weights=distance; total time=   2.0s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=10, clf__weights=uniform; total time=   1.9s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=10, clf__weights=uniform; total time=   1.5s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=10, clf__weights=uniform; total time=   1.8s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=10, clf__weights=uniform; total time=   2.0s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=10, clf__weights=distance; total time=   2.2s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=10, clf__weights=distance; total time=   2.3s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=10, clf__weights=distance; total time=   2.5s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=10, clf__weights=distance; total time=   2.3s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=10, clf__weights=distance; total time=   1.6s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=10, clf__estimator__penalty=l2; total time=  17.0s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=10, clf__estimator__penalty=l2; total time=  17.5s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=15, clf__weights=uniform; total time=   2.0s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=15, clf__weights=uniform; total time=   2.2s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=15, clf__weights=uniform; total time=   2.3s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=15, clf__weights=uniform; total time=   2.1s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=15, clf__weights=uniform; total time=   2.3s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=15, clf__weights=distance; total time=   2.1s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=MultiOutputClassifier(estimator=LogisticRegression()), clf__estimator__C=10, clf__estimator__penalty=l2; total time=  17.0s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=15, clf__weights=distance; total time=   1.6s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=15, clf__weights=distance; total time=   1.5s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=15, clf__weights=distance; total time=   1.6s
# [CV] END clf=RadiusNeighborsClassifier(), clf__radius=15, clf__weights=distance; total time=   0.9s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 45 fits failed out of a total of 340.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/pipeline.py", line 473, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 543, in fit
#     super().fit(X, Y, sample_weight=sample_weight, **fit_params)
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 278, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 136, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 67, in _fit_estimator
#     estimator.fit(X, y, **fit_params)
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.6700734  0.66984754 0.67425184 0.63376623 0.63500847 0.66431395
#  0.63404856 0.63732355 0.66312818 0.63969509 0.64093732 0.64217956
#  0.66143422 0.65708639 0.64901186 0.66149068 0.65561829 0.64782609
#  0.57515528 0.58068888 0.5741389  0.57758329 0.57679277 0.57939018
#  0.58018069 0.5717109  0.59271598 0.6107284  0.61422925 0.60750988
#  0.65601355 0.65567476 0.63359684 0.6595144  0.65578769 0.63483907
#  0.70175042 0.68661773 0.70101637 0.68560136 0.68831169 0.67092038
#         nan 0.6133258         nan 0.66425748        nan 0.71948052
#         nan 0.7190288         nan 0.71970638        nan 0.71919819
#         nan 0.71761717        nan 0.71575381        nan 0.71490683
#         nan        nan 0.55731225 0.57622812 0.55731225 0.57622812
#  0.55731225 0.57622812]
#   warnings.warn(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# RandomizedSearchCV(cv=ShuffleSplit(n_splits=5, random_state=None, test_size=0.25, train_size=None),
#                    estimator=Pipeline(steps=[('clf', None)]), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions=[{'clf': [DecisionTreeClassifier(),
#                                                  RandomForestClassifier(),
#                                                  ExtraTreeClassifier(),
#                                                  ExtraTreesClassifier()],
#                                          'clf__max_depth': [10, 30, 50],
#                                          'clf__min_samples_split': [2, 10,
#                                                                     100]},
#                                         {'...
#                                                           'distance']},
#                                         {'clf': [MultiOutputClassifier(estimator=LogisticRegression())],
#                                          'clf__estimator__C': [0.01, 0.1, 1.5,
#                                                                2.5, 3, 4.5, 6,
#                                                                7.5, 10],
#                                          'clf__estimator__penalty': ['l1',
#                                                                      'l2']},
#                                         {'clf': [RadiusNeighborsClassifier()],
#                                          'clf__radius': [1, 5, 10, 15],
#                                          'clf__weights': ['uniform',
#                                                           'distance']}],
#                    scoring=make_scorer(f1_multiclass_multioutput, response_method='predict'),
#                    verbose=2)

# %% [markdown]
# Let's see the results of the models.

# %%
output = clf.predict(x_test)

# Translate the output back to the original categories
output = pd.DataFrame(output, columns=['job_type','category'])
output['job_type'] = job_type_encoder.inverse_transform(output['job_type'])
output['category'] = category_encoder.inverse_transform(output['category'])
output
# Out:
#               job_type                                      category
# 0            Permanent                             Clinical Research
# 1            Permanent                             Clinical Research
# 2     Contract/Interim                    Manufacturing & Operations
# 3            Permanent                                       Science
# 4            Permanent                    Manufacturing & Operations
# ...                ...                                           ...
# 2356         Permanent     Medical Information and Pharmacovigilance
# 2357  Contract/Interim                                       Science
# 2358         Permanent  Pharmaceutical, Healthcare and Medical Sales
# 2359         Permanent                    Manufacturing & Operations
# 2360         Permanent    Medical Affairs / Pharmaceutical Physician
#
# [2361 rows x 2 columns]

# %% [markdown]
# ### Model Evaluation

# %%
results = pd.DataFrame(clf.cv_results_)
results = results[['rank_test_score','param_clf','mean_test_score','mean_fit_time','mean_score_time','params']].sort_values(by='rank_test_score')
results.head(5)
# Out:
#     rank_test_score                                          param_clf  \
# 51                1  MultiOutputClassifier(estimator=LogisticRegres...
# 47                2  MultiOutputClassifier(estimator=LogisticRegres...
# 53                3  MultiOutputClassifier(estimator=LogisticRegres...
# 49                4  MultiOutputClassifier(estimator=LogisticRegres...
# 55                5  MultiOutputClassifier(estimator=LogisticRegres...
#
#     mean_test_score  mean_fit_time  mean_score_time  \
# 51         0.719706      12.454108         0.046104
# 47         0.719481      11.000067         0.050486
# 53         0.719198      13.225794         0.054782
# 49         0.719029      12.207272         0.050199
# 55         0.717617      13.230894         0.077230
#
#                                                params
# 51  {'clf__estimator__penalty': 'l2', 'clf__estima...
# 47  {'clf__estimator__penalty': 'l2', 'clf__estima...
# 53  {'clf__estimator__penalty': 'l2', 'clf__estima...
# 49  {'clf__estimator__penalty': 'l2', 'clf__estima...
# 55  {'clf__estimator__penalty': 'l2', 'clf__estima...

# %%
results["param_clf_str"] = results["param_clf"].astype(str)
idx = results.groupby("param_clf_str")["mean_test_score"].idxmax()
max_results = results.loc[idx, ["param_clf_str","mean_test_score", "rank_test_score", "params"]].sort_values("mean_test_score", ascending=False)

plt.bar(max_results["param_clf_str"], max_results["mean_test_score"])
plt.ylabel("F1 Score")
plt.xticks(rotation=90)
plt.show()

# %%
score = clf.score(x_test, y_test)
print(clf.best_estimator_)
print("Best model's score on the test dataset: ", score)
# Out:
# Pipeline(steps=[('clf',
#                  MultiOutputClassifier(estimator=LogisticRegression(C=1.5)))])
# Best model's score on the test dataset:  0.7124099957645066

# %% [markdown]
# ### What happens when we train each label separately?

# %%
knn = KNeighborsClassifier(n_neighbors=5, weights='distance')
knn.fit(x_train, y_train)
knn.score(x_test, y_test)

column_score = []
for column in y.columns:
    print(f"Training model with label: {column}")
    model = KNeighborsClassifier(n_neighbors=5)
    model.fit(x_train, y_train[column])
    
    output = model.predict(x_test)
    score = f1_score(y_test[column], output, average='micro')
    column_score.append(score)
    print(f"Test score on column {column}: {score:.3f}")
    
print(f"Average test score: {np.mean(column_score)}")
# Out:
# Training model with label: job_type
# Test score on column job_type: 0.969
# Training model with label: category
# Test score on column category: 0.454
# Average test score: 0.7113511224057603

# %% [markdown]
# `MultiOutputClassifier` essentially does the same thing as training each label separately, then combining the outputs.  Therefore, models who support and do not support multi-class multi-output classification should have

# %% [markdown]
# <div class="alert alert-info">
#
# ## Part 2: Model Training - Dependent Labels
#
# In this part, we are going to train multiclass multioutput as if the labels are *dependent* from each other using classifier chains.  **Classifier chains** are a clever approach to multi-label classification that aims to improve upon the simpler "one-vs-rest" strategy by explicitly considering dependencies between labels. They strike a balance between the simplicity of one-vs-rest and the complexity of fully joint probability models.
#
# *This approach involves chaining together off-the-shelf binary classifiers in a directed structure, such that individual label predictions become features for other classifiers* (Read, et al., 2020).
#
# Similar to Part 1, we will use `sklearn.multioutput.ClassifierChain` instead of `sklearn.multioutput.MultiOutputClassifier`.  The `ClassifierChain` is a meta-estimator that takes an arbitrary base classifier and chains it to predict multiple labels.  The order of the labels is determined by the order of the columns in the dataset.  Note that unlike `MultiOutputClassifier`, we have to wrap all classifiers in `ClassifierChain`.

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.25) # test size equal to the validation set
param_grid = [
    {
        "clf": [ClassifierChain(DecisionTreeClassifier()), 
                ClassifierChain(RandomForestClassifier()), 
                ClassifierChain(ExtraTreeClassifier()), 
                ClassifierChain(ExtraTreesClassifier())
            ],
        'clf__base_estimator__max_depth': [10, 30, 50],
        'clf__base_estimator__min_samples_split': [2, 10, 100],
    },
    {
        "clf": [ClassifierChain(KNeighborsClassifier())],
        'clf__base_estimator__n_neighbors': [5, 10, 100],
        'clf__base_estimator__weights': ['uniform', 'distance'],
    },
    {
        "clf": [ClassifierChain(LogisticRegression())],
        "clf__base_estimator__penalty": ['l1','l2'],
        "clf__base_estimator__C": [0.01, 0.1, 1.5, 2.5, 3, 4.5, 6, 7.5, 10],
    },
    {
        "clf": [ClassifierChain(RadiusNeighborsClassifier())],
        'clf__base_estimator__radius': [1,5,10,15],
        'clf__base_estimator__weights': ['uniform', 'distance'],
    },
]

steps = [('clf', None)]
pipe = Pipeline(steps)
clf = RandomizedSearchCV(pipe,
                         param_distributions=param_grid,
                         n_iter=30,
                         cv=cv,
                         n_jobs=-1,
                         scoring=make_scorer(f1_multiclass_multioutput),
                         verbose=2,
                         random_state=RANDOM_STATE) # ,
clf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=15, clf__base_estimator__weights=uniform; total time=   3.0s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=15, clf__base_estimator__weights=uniform; total time=   3.0s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=15, clf__base_estimator__weights=uniform; total time=   3.5s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=15, clf__base_estimator__weights=uniform; total time=   2.5s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=15, clf__base_estimator__weights=uniform; total time=   2.6s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=4.5, clf__base_estimator__penalty=l2; total time=   8.5s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=4.5, clf__base_estimator__penalty=l2; total time=   8.6s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=4.5, clf__base_estimator__penalty=l2; total time=   8.7s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=4.5, clf__base_estimator__penalty=l2; total time=   8.8s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=4.5, clf__base_estimator__penalty=l2; total time=   9.1s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=5, clf__base_estimator__weights=uniform; total time=   1.9s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=5, clf__base_estimator__weights=uniform; total time=   2.1s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=5, clf__base_estimator__weights=uniform; total time=   2.6s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=3, clf__base_estimator__penalty=l1; total time=   0.0s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=3, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=3, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=3, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=3, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=5, clf__base_estimator__weights=uniform; total time=   2.2s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=5, clf__base_estimator__weights=uniform; total time=   2.4s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time=  15.1s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=2; total time=   7.8s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time=  14.1s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=2; total time=   7.5s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=10; total time=   0.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=10; total time=   0.2s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=10; total time=   0.2s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=10; total time=   0.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=10; total time=   0.2s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=2; total time=   7.5s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time=  15.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time=  15.1s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time=  15.6s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=0.1, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=0.1, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=0.1, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=0.1, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=0.1, clf__base_estimator__penalty=l1; total time=   0.0s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=2; total time=   7.8s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=2; total time=   7.6s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=100; total time=  12.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=100; total time=  12.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=100; total time=  12.5s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=100, clf__base_estimator__weights=distance; total time=   2.1s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=100; total time=  12.4s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=100; total time=  12.5s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=100, clf__base_estimator__weights=distance; total time=   2.6s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=100, clf__base_estimator__weights=distance; total time=   2.5s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/pipeline.py", line 601, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 829, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 679, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 693, in predict
#     probs = self.predict_proba(X)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 782, in predict_proba
#     raise ValueError(
# ValueError: No neighbors found for test samples array([  31,   48,   49,   71,  147,  155,  170,  175,  189,  227,  230,
#         232,  319,  338,  363,  399,  413,  496,  505,  533,  546,  579,
#         604,  608,  665,  676,  688,  744,  765,  774,  797,  833,  839,
#         879,  894,  897,  972,  989, 1011, 1096, 1116, 1122, 1180, 1185,
#        1205, 1218, 1251, 1255, 1262, 1309, 1314, 1382, 1398, 1404, 1459,
#        1473, 1476, 1584, 1591, 1606, 1656, 1658, 1692, 1695, 1719, 1729,
#        1736, 1770]), you can try using larger radius, giving a label for outliers, or considering removing them from your dataset.
#
#   warnings.warn(
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=1, clf__base_estimator__weights=uniform; total time=   0.6s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=100, clf__base_estimator__weights=distance; total time=   3.0s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/pipeline.py", line 601, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 829, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 679, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 693, in predict
#     probs = self.predict_proba(X)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 782, in predict_proba
#     raise ValueError(
# ValueError: No neighbors found for test samples array([  15,   28,   35,   50,   84,   96,  114,  122,  142,  164,  172,
#         213,  270,  272,  313,  325,  344,  345,  412,  434,  449,  502,
#         523,  537,  544,  563,  592,  596,  613,  632,  642,  644,  674,
#         675,  774,  775,  812,  836,  842,  844,  850,  863,  887,  950,
#         978,  981,  995, 1000, 1036, 1045, 1062, 1065, 1101, 1132, 1137,
#        1153, 1193, 1259, 1260, 1263, 1271, 1279, 1286, 1347, 1388, 1401,
#        1411, 1415, 1434, 1450, 1507, 1529, 1537, 1542, 1546, 1564, 1572,
#        1596, 1608, 1644, 1659, 1675, 1736, 1748, 1756, 1761]), you can try using larger radius, giving a label for outliers, or considering removing them from your dataset.
#
#   warnings.warn(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/pipeline.py", line 601, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 829, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 679, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 693, in predict
#     probs = self.predict_proba(X)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 782, in predict_proba
#     raise ValueError(
# ValueError: No neighbors found for test samples array([   4,   36,   60,   73,  108,  124,  141,  144,  145,  147,  159,
#         167,  181,  188,  229,  259,  262,  300,  313,  317,  355,  373,
#         391,  402,  409,  424,  439,  449,  451,  477,  509,  518,  520,
#         537,  542,  587,  607,  614,  647,  703,  710,  720,  732,  800,
#         806,  859,  867,  897,  910,  915,  924,  944,  997, 1038, 1047,
#        1092, 1127, 1138, 1152, 1168, 1170, 1197, 1206, 1217, 1250, 1296,
#        1304, 1306, 1316, 1374, 1389, 1393, 1399, 1403, 1404, 1414, 1428,
#        1477, 1478, 1481, 1504, 1576, 1615, 1623, 1628, 1637, 1687, 1690,
#        1698, 1700, 1705, 1721, 1743, 1752]), you can try using larger radius, giving a label for outliers, or considering removing them from your dataset.
#
#   warnings.warn(
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=1, clf__base_estimator__weights=uniform; total time=   0.6s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=1, clf__base_estimator__weights=uniform; total time=   0.6s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/pipeline.py", line 601, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 829, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 679, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 693, in predict
#     probs = self.predict_proba(X)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 782, in predict_proba
#     raise ValueError(
# ValueError: No neighbors found for test samples array([  23,   24,   56,   58,   70,   71,  183,  185,  208,  213,  220,
#         221,  224,  230,  252,  257,  260,  266,  277,  301,  307,  313,
#         323,  333,  374,  400,  410,  411,  412,  428,  442,  450,  464,
#         486,  498,  501,  579,  634,  641,  715,  717,  774,  864,  870,
#         912,  936,  957,  976,  983,  994,  995, 1011, 1062, 1065, 1101,
#        1117, 1126, 1143, 1185, 1196, 1201, 1217, 1286, 1292, 1300, 1301,
#        1315, 1338, 1408, 1409, 1413, 1415, 1425, 1461, 1489, 1508, 1571,
#        1576, 1580, 1586, 1589, 1591, 1593, 1600, 1605, 1606, 1618, 1632,
#        1653, 1656, 1680, 1687, 1696, 1721, 1723, 1728, 1743, 1752, 1754]), you can try using larger radius, giving a label for outliers, or considering removing them from your dataset.
#
#   warnings.warn(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/pipeline.py", line 601, in predict
#     return self.steps[-1][1].predict(Xt, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 829, in predict
#     return self._get_predictions(X, output_method="predict")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 679, in _get_predictions
#     feature_predictions, _ = _get_response_values(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/utils/_response.py", line 211, in _get_response_values
#     y_pred = prediction_method(X)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 693, in predict
#     probs = self.predict_proba(X)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py", line 782, in predict_proba
#     raise ValueError(
# ValueError: No neighbors found for test samples array([  22,   26,   66,   80,   88,  106,  119,  144,  169,  172,  183,
#         200,  207,  216,  220,  221,  223,  226,  237,  258,  279,  280,
#         319,  354,  357,  378,  382,  404,  410,  425,  441,  460,  525,
#         535,  546,  549,  554,  558,  563,  564,  567,  568,  593,  599,
#         619,  633,  660,  664,  702,  738,  753,  770,  807,  827,  828,
#         842,  857,  878,  895,  906,  923,  949,  973,  976, 1034, 1044,
#        1079, 1082, 1115, 1143, 1149, 1162, 1187, 1198, 1205, 1216, 1225,
#        1231, 1237, 1264, 1272, 1277, 1283, 1289, 1319, 1339, 1344, 1347,
#        1356, 1359, 1366, 1370, 1378, 1389, 1391, 1402, 1448, 1482, 1492,
#        1493, 1510, 1550, 1552, 1553, 1572, 1578, 1588, 1592, 1618, 1656,
#        1664, 1693, 1713, 1728, 1729, 1731, 1732, 1754, 1765]), you can try using larger radius, giving a label for outliers, or considering removing them from your dataset.
#
#   warnings.warn(
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=1, clf__base_estimator__weights=uniform; total time=   0.7s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=100, clf__base_estimator__weights=distance; total time=   2.3s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=1, clf__base_estimator__weights=uniform; total time=   0.7s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=10, clf__base_estimator__penalty=l2; total time=   8.6s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=10, clf__base_estimator__penalty=l2; total time=   9.1s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=10, clf__base_estimator__penalty=l2; total time=   9.5s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=10, clf__base_estimator__penalty=l2; total time=   7.9s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=10, clf__base_estimator__penalty=l2; total time=   8.5s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=10; total time=  22.0s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=10; total time=  20.9s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=10; total time=  21.2s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=6, clf__base_estimator__penalty=l2; total time=   7.0s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=6, clf__base_estimator__penalty=l2; total time=   7.8s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=10; total time=  24.3s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=6, clf__base_estimator__penalty=l2; total time=   7.6s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=10; total time=  25.0s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=6, clf__base_estimator__penalty=l2; total time=   8.4s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=6, clf__base_estimator__penalty=l2; total time=   7.8s
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time= 1.5min
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time= 1.6min
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=2; total time=  17.7s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=2; total time=  17.6s
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time= 1.6min
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time= 1.6min
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=2; total time=  18.1s
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time= 1.6min
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=10; total time=   0.2s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=10; total time=   0.2s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=10; total time=   0.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=10; total time=   0.2s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=10; total time=   0.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time=   0.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time=   0.2s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time=   0.2s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time=   0.4s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time=   0.2s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=2; total time=  18.2s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=10, clf__base_estimator__weights=distance; total time=   1.9s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=10, clf__base_estimator__weights=distance; total time=   2.2s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=10, clf__base_estimator__weights=distance; total time=   1.9s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=10, clf__base_estimator__weights=distance; total time=   1.9s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=10, clf__base_estimator__weights=distance; total time=   2.2s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=100, clf__base_estimator__weights=uniform; total time=   2.3s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=100, clf__base_estimator__weights=uniform; total time=   2.5s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=2; total time=  19.2s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=100, clf__base_estimator__weights=uniform; total time=   2.8s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=100, clf__base_estimator__weights=uniform; total time=   2.8s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=2; total time=   0.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=2; total time=   0.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=2; total time=   0.3s
# [CV] END clf=ClassifierChain(base_estimator=KNeighborsClassifier()), clf__base_estimator__n_neighbors=100, clf__base_estimator__weights=uniform; total time=   2.7s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=2; total time=   0.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreeClassifier()), clf__base_estimator__max_depth=10, clf__base_estimator__min_samples_split=2; total time=   0.2s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=2; total time=  55.3s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=2; total time=  56.3s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=2; total time=  59.1s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=2; total time=  56.1s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=30, clf__base_estimator__min_samples_split=2; total time=  59.2s
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=2; total time= 1.9min
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=2; total time= 2.0min
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=2; total time= 2.0min
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=7.5, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=7.5, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=7.5, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=7.5, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=7.5, clf__base_estimator__penalty=l1; total time=   0.1s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=10, clf__base_estimator__weights=distance; total time=   3.4s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=10, clf__base_estimator__weights=distance; total time=   4.5s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=10, clf__base_estimator__weights=distance; total time=   3.9s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=10, clf__base_estimator__weights=distance; total time=   4.0s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=10, clf__base_estimator__weights=distance; total time=   5.5s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=15, clf__base_estimator__weights=distance; total time=   4.6s
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=100; total time= 1.9min
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=15, clf__base_estimator__weights=distance; total time=   4.3s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=15, clf__base_estimator__weights=distance; total time=   3.8s
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=100; total time= 2.0min
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=15, clf__base_estimator__weights=distance; total time=   4.3s
# [CV] END clf=ClassifierChain(base_estimator=RadiusNeighborsClassifier()), clf__base_estimator__radius=15, clf__base_estimator__weights=distance; total time=   3.8s
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=2; total time= 2.1min
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=100; total time= 2.0min
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=2; total time= 2.2min
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=1.5, clf__base_estimator__penalty=l2; total time=  11.5s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=1.5, clf__base_estimator__penalty=l2; total time=  11.8s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=1.5, clf__base_estimator__penalty=l2; total time=  11.5s
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=1.5, clf__base_estimator__penalty=l2; total time=  11.5s
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END clf=ClassifierChain(base_estimator=LogisticRegression()), clf__base_estimator__C=1.5, clf__base_estimator__penalty=l2; total time=  11.3s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=2; total time=  21.9s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=2; total time=  22.0s
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=2; total time=  25.3s
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=100; total time= 2.2min
# [CV] END clf=ClassifierChain(base_estimator=RandomForestClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=100; total time= 2.2min
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time= 1.6min
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time= 1.6min
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time= 1.6min
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=2; total time=  24.5s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time= 1.6min
# [CV] END clf=ClassifierChain(base_estimator=ExtraTreesClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=2; total time=  22.6s
# [CV] END clf=ClassifierChain(base_estimator=DecisionTreeClassifier()), clf__base_estimator__max_depth=50, clf__base_estimator__min_samples_split=10; total time= 1.7min
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 15 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/pipeline.py", line 473, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 1030, in fit
#     super().fit(X, Y, **fit_params)
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/multioutput.py", line 791, in fit
#     estimator.fit(
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.72382835 0.55731225 0.65194805 0.70197628        nan 0.61038961
#  0.57374365 0.62998306        nan 0.65573123 0.66809712        nan
#  0.72501412 0.65669113 0.72659514 0.65335968 0.63128176 0.57295313
#  0.57363072 0.68306042 0.68582722 0.56973461 0.66115189 0.65375494
#         nan 0.5757764  0.5757764  0.71981931 0.62834557 0.656917  ]
#   warnings.warn(
# /opt/anaconda3/envs/msds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# RandomizedSearchCV(cv=ShuffleSplit(n_splits=5, random_state=None, test_size=0.25, train_size=None),
#                    estimator=Pipeline(steps=[('clf', None)]), n_iter=30,
#                    n_jobs=-1,
#                    param_distributions=[{'clf': [ClassifierChain(base_estimator=DecisionTreeClassifier()),
#                                                  ClassifierChain(base_estimator=RandomForestClassifier()),
#                                                  ClassifierChain(base_estimator=ExtraTreeClassifier...
#                                          'clf__base_estimator__C': [0.01, 0.1,
#                                                                     1.5, 2.5, 3,
#                                                                     4.5, 6, 7.5,
#                                                                     10],
#                                          'clf__base_estimator__penalty': ['l1',
#                                                                           'l2']},
#                                         {'clf': [ClassifierChain(base_estimator=RadiusNeighborsClassifier())],
#                                          'clf__base_estimator__radius': [1, 5,
#                                                                          10,
#                                                                          15],
#                                          'clf__base_estimator__weights': ['uniform',
#                                                                           'distance']}],
#                    random_state=420,
#                    scoring=make_scorer(f1_multiclass_multioutput, response_method='predict'),
#                    verbose=2)

# %%
results = pd.DataFrame(clf.cv_results_)
results = results[['rank_test_score','param_clf','mean_test_score','mean_fit_time','mean_score_time','params']].sort_values(by='rank_test_score')
results.head(5)
# Out:
#     rank_test_score                                          param_clf  \
# 14                1  ClassifierChain(base_estimator=LogisticRegress...
# 12                2  ClassifierChain(base_estimator=LogisticRegress...
# 0                 3  ClassifierChain(base_estimator=LogisticRegress...
# 27                4  ClassifierChain(base_estimator=LogisticRegress...
# 3                 5  ClassifierChain(base_estimator=KNeighborsClass...
#
#     mean_test_score  mean_fit_time  mean_score_time  \
# 14         0.726595       7.636322         0.076201
# 12         0.725014       8.649368         0.084429
# 0          0.723828       8.652516         0.074678
# 27         0.719819      11.443778         0.087004
# 3          0.701976       0.117255         2.122491
#
#                                                params
# 14  {'clf__base_estimator__penalty': 'l2', 'clf__b...
# 12  {'clf__base_estimator__penalty': 'l2', 'clf__b...
# 0   {'clf__base_estimator__penalty': 'l2', 'clf__b...
# 27  {'clf__base_estimator__penalty': 'l2', 'clf__b...
# 3   {'clf__base_estimator__weights': 'uniform', 'c...

# %%
results["param_clf_str"] = results["param_clf"].astype(str)
idx = results.groupby("param_clf_str")["mean_test_score"].idxmax()
max_results = results.loc[idx, ["param_clf_str","mean_test_score", "rank_test_score", "params"]].sort_values("mean_test_score", ascending=False)

plt.bar(max_results["param_clf_str"], max_results["mean_test_score"])
plt.ylabel("F1 Score")
plt.xticks(rotation=90)
plt.show()

# %%
score = clf.score(x_test, y_test)
print(clf.best_estimator_)
print("Best model's score on the test dataset: ", score)
# Out:
# Pipeline(steps=[('clf',
#                  ClassifierChain(base_estimator=LogisticRegression(C=6)))])
# Best model's score on the test dataset:  0.717704362558238

# %% [markdown]
# <div class="alert alert-info">
#
# ## Results and Discussion
#
# </div>

# %% [markdown]
# Based on the results of the exploratory data analysis, the dataset is imbalanced in terms of job types and categories. The distribution of job types is skewed towards "Permanent" roles, while certain job categories are more prevalent than others. This imbalance could affect the model's performance, especially for less common job types or categories. The Chi-Square test of independence revealed that the job type and job category labels are independent of each other.
#
# The results of the Singular Vector Decomposition (SVD) showed that the first 1768 components explain 85% of the variance in the dataset. This reduction in dimensionality can help improve the model's performance by capturing the most important features while reducing noise.
#
# The dataset is trained in two phases: one where the labels are treated independently and another where they are treated as dependent. Results show that the `LogisticRegression` model performed best in both scenarios, with the highest average F1 score. Other tree-related models also performed well.
#
# The fact that classifier chains (which model dependencies between labels) didn't significantly outperform the multioutput classifier (which assumes independence) suggests that the ***relationships between the labels might be weak or not strongly predictive***.  This is consistent with the results of the Chi-Square test of independence, which indicated that the two labels are not significantly associated with each other.
#
# In this case, the added complexity of modeling dependencies might not be necessary. Simpler models like the multioutput classifier could be sufficient for this type of dataset.

# %% [markdown]
# <div class="alert alert-info">
#
# ## Conclusion (Please Update the Conclusion to include importance of the dependency of the labels)
#
# </div>

# %% [markdown]
# This study aimed to predict the industry and employment status of job listings based solely on their textual descriptions. To address this multi-output classification problem, a MultiOutput Logistic Regression model was employed.
#
# - Model Performance: The MultiOutput Logistic Regression model demonstrated strong performance, outperforming other models like K-Nearest Neighbors and Decision Trees.
#
# - Computational Efficiency: It is essential to find a balance between accuracy and computational efficiency as MultiOutput Logistic Regression models can be computationally intensive. Consider strategies to optimize the model's computational efficiency, such as feature selection or dimensionality reduction.
#
# - Multi-Output vs. Single-Output: Comparing the performance of the multi-output model to separate single-output models for each label revealed a slight improvement in accuracy. This suggests that the multi-output approach can effectively capture the interdependencies between the two target variables, leading to better overall performance.
#
# In conclusion, this study has demonstrated the effectiveness of MultiOutput Logistic Regression for predicting multiple target variables from text data. By leveraging the strengths of this approach and exploring future advancements, it is possible to further improve the accuracy and efficiency of job classification models.

# %% [markdown]
# ## References:
#
# 1.  [Read, J., Pfahringer, B., Holmes, G., & Frank, E. (2020). Classifier chains: A review and perspectives. arXiv.](https://arxiv.org/pdf/1912.13405)
# 2.  Scikit-learn developers. (2024). 1.12. Multiclass and multioutput algorithms — scikit-learn 1.5.2 documentation. Retrieved November 25, 2024, from https://scikit-learn.org/1.5/modules/multiclass.html
